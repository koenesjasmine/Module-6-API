# %% [markdown]
# # Deliverable 1

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import timeit.
import timeit
from citipy import citipy
import time
from datetime import datetime
import requests

# %%
from config import weather_api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10804\3439195162.py in <module>
# ----> 1 from config import weather_api_key
#
# ModuleNotFoundError: No module named 'config'

# %%
# Create a set of random latitude and longitude combinations.
place_count = 2000 
lats = np.random.uniform(low=-90.000, high=90.000, size=place_count)
lngs = np.random.uniform(low=-180.000, high=180.000, size=place_count)
coordinates = zip(lats, lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 789

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_des = city_weather["weather"][0]['main']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "City_weather":city_des})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint george
# Processing Record 2 of Set 1 | bozeman
# Processing Record 3 of Set 1 | taltal
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | hofn
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | kalispell
# Processing Record 8 of Set 1 | poum
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | bambous virieux
# Processing Record 13 of Set 1 | chuy
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | sturgeon falls
# Processing Record 16 of Set 1 | kurilsk
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | puerto baquerizo moreno
# Processing Record 20 of Set 1 | kotido
# Processing Record 21 of Set 1 | cayenne
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | alenquer
# Processing Record 24 of Set 1 | saskylakh
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | hokitika
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | ibatiba
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | guerrero negro
# Processing Record 33 of Set 1 | coquimbo
# Processing Record 34 of Set 1 | san quintin
# Processing Record 35 of Set 1 | langxiang
# Processing Record 36 of Set 1 | bengkulu
# Processing Record 37 of Set 1 | kloulklubed
# Processing Record 38 of Set 1 | vostok
# Processing Record 39 of Set 1 | uddevalla
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | kaitangata
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | sinnai
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | mazatlan
# Processing Record 50 of Set 1 | coxim
# Processing Record 1 of Set 2 | zyryanka
# Processing Record 2 of Set 2 | isangel
# Processing Record 3 of Set 2 | constitucion
# Processing Record 4 of Set 2 | kavaratti
# Processing Record 5 of Set 2 | mbuguni
# Processing Record 6 of Set 2 | batagay-alyta
# Processing Record 7 of Set 2 | tambul
# City not found. Skipping...
# Processing Record 8 of Set 2 | saint-augustin
# Processing Record 9 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 2 | vardo
# Processing Record 11 of Set 2 | iqaluit
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | soyo
# Processing Record 15 of Set 2 | sitka
# Processing Record 16 of Set 2 | ilka
# City not found. Skipping...
# Processing Record 17 of Set 2 | haines junction
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | komsomolskiy
# Processing Record 20 of Set 2 | deputatskiy
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | hamilton
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | hambantota
# Processing Record 29 of Set 2 | beihai
# Processing Record 30 of Set 2 | grand gaube
# Processing Record 31 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | caraballeda
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | kuliyapitiya
# Processing Record 38 of Set 2 | jacareacanga
# Processing Record 39 of Set 2 | suba
# Processing Record 40 of Set 2 | aspindza
# Processing Record 41 of Set 2 | barrow
# Processing Record 42 of Set 2 | bilibino
# Processing Record 43 of Set 2 | airai
# Processing Record 44 of Set 2 | balkhash
# Processing Record 45 of Set 2 | palmer
# Processing Record 46 of Set 2 | pitimbu
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | north platte
# Processing Record 49 of Set 2 | toora-khem
# Processing Record 50 of Set 2 | armizonskoye
# Processing Record 1 of Set 3 | punta arenas
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | brae
# Processing Record 6 of Set 3 | invercargill
# Processing Record 7 of Set 3 | shingu
# Processing Record 8 of Set 3 | laje
# Processing Record 9 of Set 3 | zeya
# Processing Record 10 of Set 3 | ust-kut
# Processing Record 11 of Set 3 | kovdor
# Processing Record 12 of Set 3 | ilhabela
# Processing Record 13 of Set 3 | hermanus
# Processing Record 14 of Set 3 | malpe
# Processing Record 15 of Set 3 | livingstone
# Processing Record 16 of Set 3 | souillac
# Processing Record 17 of Set 3 | rundu
# Processing Record 18 of Set 3 | clyde river
# Processing Record 19 of Set 3 | bethel
# Processing Record 20 of Set 3 | yerbogachen
# Processing Record 21 of Set 3 | severo-kurilsk
# Processing Record 22 of Set 3 | sao joao da barra
# Processing Record 23 of Set 3 | vaini
# Processing Record 24 of Set 3 | pacifica
# Processing Record 25 of Set 3 | camacha
# Processing Record 26 of Set 3 | itarema
# Processing Record 27 of Set 3 | ternate
# Processing Record 28 of Set 3 | turtas
# Processing Record 29 of Set 3 | moyale
# Processing Record 30 of Set 3 | riyadh
# Processing Record 31 of Set 3 | nuuk
# Processing Record 32 of Set 3 | port-gentil
# Processing Record 33 of Set 3 | ilulissat
# Processing Record 34 of Set 3 | jalu
# Processing Record 35 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 3 | chokurdakh
# Processing Record 37 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 3 | teya
# Processing Record 39 of Set 3 | avarua
# Processing Record 40 of Set 3 | okha
# Processing Record 41 of Set 3 | sedelnikovo
# City not found. Skipping...
# Processing Record 42 of Set 3 | san jeronimo
# Processing Record 43 of Set 3 | port hardy
# Processing Record 44 of Set 3 | maxixe
# Processing Record 45 of Set 3 | warrington
# Processing Record 46 of Set 3 | balancan
# Processing Record 47 of Set 3 | pujili
# Processing Record 48 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 49 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 3 | buchanan
# Processing Record 1 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 4 | aklavik
# Processing Record 3 of Set 4 | kruisfontein
# Processing Record 4 of Set 4 | esperance
# Processing Record 5 of Set 4 | mamallapuram
# Processing Record 6 of Set 4 | thinadhoo
# Processing Record 7 of Set 4 | vila velha
# Processing Record 8 of Set 4 | hami
# Processing Record 9 of Set 4 | raudeberg
# Processing Record 10 of Set 4 | upernavik
# Processing Record 11 of Set 4 | sioux lookout
# Processing Record 12 of Set 4 | cherskiy
# Processing Record 13 of Set 4 | provideniya
# Processing Record 14 of Set 4 | zlitan
# Processing Record 15 of Set 4 | bredasdorp
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | iralaya
# Processing Record 18 of Set 4 | fortuna
# Processing Record 19 of Set 4 | chanute
# Processing Record 20 of Set 4 | carnarvon
# Processing Record 21 of Set 4 | hays
# Processing Record 22 of Set 4 | vanimo
# Processing Record 23 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 4 | amahai
# Processing Record 25 of Set 4 | el retorno
# Processing Record 26 of Set 4 | richards bay
# Processing Record 27 of Set 4 | sogdiondon
# City not found. Skipping...
# Processing Record 28 of Set 4 | ahipara
# Processing Record 29 of Set 4 | pailon
# Processing Record 30 of Set 4 | port elizabeth
# Processing Record 31 of Set 4 | uarini
# Processing Record 32 of Set 4 | codrington
# Processing Record 33 of Set 4 | patacamaya
# Processing Record 34 of Set 4 | khani
# Processing Record 35 of Set 4 | saint anthony
# Processing Record 36 of Set 4 | buariki
# City not found. Skipping...
# Processing Record 37 of Set 4 | concarneau
# Processing Record 38 of Set 4 | alta floresta
# Processing Record 39 of Set 4 | shenjiamen
# Processing Record 40 of Set 4 | fuling
# Processing Record 41 of Set 4 | tautira
# Processing Record 42 of Set 4 | najran
# Processing Record 43 of Set 4 | narasannapeta
# Processing Record 44 of Set 4 | caravelas
# Processing Record 45 of Set 4 | progreso
# Processing Record 46 of Set 4 | pisco
# Processing Record 47 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 48 of Set 4 | baruun-urt
# Processing Record 49 of Set 4 | port alfred
# Processing Record 50 of Set 4 | talnakh
# Processing Record 1 of Set 5 | faanui
# Processing Record 2 of Set 5 | derzhavinsk
# Processing Record 3 of Set 5 | flinders
# Processing Record 4 of Set 5 | ler
# Processing Record 5 of Set 5 | daru
# Processing Record 6 of Set 5 | logan
# Processing Record 7 of Set 5 | ninotsminda
# Processing Record 8 of Set 5 | margate
# Processing Record 9 of Set 5 | verkhnyaya inta
# Processing Record 10 of Set 5 | hannibal
# Processing Record 11 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 5 | eureka
# Processing Record 13 of Set 5 | liusha
# Processing Record 14 of Set 5 | bom jesus
# Processing Record 15 of Set 5 | nara
# Processing Record 16 of Set 5 | zambezi
# Processing Record 17 of Set 5 | shimanovsk
# Processing Record 18 of Set 5 | lago da pedra
# Processing Record 19 of Set 5 | half moon bay
# Processing Record 20 of Set 5 | chekhov
# Processing Record 21 of Set 5 | brindisi
# Processing Record 22 of Set 5 | puerto ayacucho
# Processing Record 23 of Set 5 | cartersville
# Processing Record 24 of Set 5 | georgetown
# Processing Record 25 of Set 5 | salalah
# Processing Record 26 of Set 5 | kalayaan
# Processing Record 27 of Set 5 | palmares do sul
# Processing Record 28 of Set 5 | harper
# Processing Record 29 of Set 5 | sisimiut
# Processing Record 30 of Set 5 | pevek
# Processing Record 31 of Set 5 | bull savanna
# Processing Record 32 of Set 5 | cabedelo
# Processing Record 33 of Set 5 | kota kinabalu
# Processing Record 34 of Set 5 | halifax
# Processing Record 35 of Set 5 | svetlyy
# Processing Record 36 of Set 5 | inyonga
# Processing Record 37 of Set 5 | acapulco
# Processing Record 38 of Set 5 | klyuchi
# Processing Record 39 of Set 5 | chimbote
# Processing Record 40 of Set 5 | ambanja
# Processing Record 41 of Set 5 | lompoc
# Processing Record 42 of Set 5 | merritt island
# Processing Record 43 of Set 5 | french harbor
# Processing Record 44 of Set 5 | henties bay
# Processing Record 45 of Set 5 | sudislavl
# Processing Record 46 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 47 of Set 5 | dawei
# Processing Record 48 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 5 | sorland
# Processing Record 50 of Set 5 | cockburn town
# Processing Record 1 of Set 6 | carupano
# Processing Record 2 of Set 6 | brownsville
# Processing Record 3 of Set 6 | dalvik
# Processing Record 4 of Set 6 | sukumo
# Processing Record 5 of Set 6 | paamiut
# Processing Record 6 of Set 6 | tamiahua
# Processing Record 7 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 8 of Set 6 | dikson
# Processing Record 9 of Set 6 | umm lajj
# Processing Record 10 of Set 6 | pizarro
# Processing Record 11 of Set 6 | hobyo
# Processing Record 12 of Set 6 | nguruka
# Processing Record 13 of Set 6 | hindaun
# Processing Record 14 of Set 6 | changli
# Processing Record 15 of Set 6 | santa rosa
# Processing Record 16 of Set 6 | havre-saint-pierre
# Processing Record 17 of Set 6 | vestmannaeyjar
# Processing Record 18 of Set 6 | mbuji-mayi
# Processing Record 19 of Set 6 | tabou
# Processing Record 20 of Set 6 | dunedin
# Processing Record 21 of Set 6 | norrtalje
# Processing Record 22 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 6 | pemangkat
# Processing Record 24 of Set 6 | mosquera
# Processing Record 25 of Set 6 | caledon east
# Processing Record 26 of Set 6 | matina
# Processing Record 27 of Set 6 | ryotsu
# Processing Record 28 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 6 | formosa
# Processing Record 30 of Set 6 | muros
# Processing Record 31 of Set 6 | yarada
# Processing Record 32 of Set 6 | tikapur
# Processing Record 33 of Set 6 | schwerin
# Processing Record 34 of Set 6 | college
# Processing Record 35 of Set 6 | aberdeen
# Processing Record 36 of Set 6 | puerto del rosario
# Processing Record 37 of Set 6 | warwick
# Processing Record 38 of Set 6 | roma
# Processing Record 39 of Set 6 | awbari
# Processing Record 40 of Set 6 | asau
# Processing Record 41 of Set 6 | votice
# Processing Record 42 of Set 6 | wilmington
# Processing Record 43 of Set 6 | karpuninskiy
# City not found. Skipping...
# Processing Record 44 of Set 6 | ongole
# Processing Record 45 of Set 6 | beringovskiy
# Processing Record 46 of Set 6 | carauari
# Processing Record 47 of Set 6 | novaya lyalya
# Processing Record 48 of Set 6 | vitim
# Processing Record 49 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 50 of Set 6 | porto novo
# Processing Record 1 of Set 7 | bafia
# Processing Record 2 of Set 7 | basco
# Processing Record 3 of Set 7 | izumo
# Processing Record 4 of Set 7 | tessalit
# Processing Record 5 of Set 7 | muisne
# Processing Record 6 of Set 7 | yanam
# Processing Record 7 of Set 7 | mersing
# Processing Record 8 of Set 7 | devils lake
# Processing Record 9 of Set 7 | namanga
# Processing Record 10 of Set 7 | ichinoseki
# Processing Record 11 of Set 7 | floro
# Processing Record 12 of Set 7 | portree
# Processing Record 13 of Set 7 | ardmore
# Processing Record 14 of Set 7 | kununurra
# Processing Record 15 of Set 7 | samarai
# Processing Record 16 of Set 7 | petrivka
# Processing Record 17 of Set 7 | kieta
# Processing Record 18 of Set 7 | amapa
# Processing Record 19 of Set 7 | aguimes
# Processing Record 20 of Set 7 | hasaki
# Processing Record 21 of Set 7 | namibe
# Processing Record 22 of Set 7 | costa rica
# Processing Record 23 of Set 7 | karratha
# Processing Record 24 of Set 7 | maputo
# Processing Record 25 of Set 7 | itoman
# Processing Record 26 of Set 7 | wiarton
# Processing Record 27 of Set 7 | laguna
# Processing Record 28 of Set 7 | kars
# Processing Record 29 of Set 7 | billings
# Processing Record 30 of Set 7 | ilo
# Processing Record 31 of Set 7 | sao filipe
# Processing Record 32 of Set 7 | klaksvik
# Processing Record 33 of Set 7 | vartop
# Processing Record 34 of Set 7 | saint-joseph
# Processing Record 35 of Set 7 | ixtapa
# Processing Record 36 of Set 7 | saint pete beach
# Processing Record 37 of Set 7 | asfi
# Processing Record 38 of Set 7 | naryan-mar
# Processing Record 39 of Set 7 | torbay
# Processing Record 40 of Set 7 | harwich
# Processing Record 41 of Set 7 | dvinskoy
# Processing Record 42 of Set 7 | leningradskiy
# Processing Record 43 of Set 7 | port hedland
# Processing Record 44 of Set 7 | porto walter
# Processing Record 45 of Set 7 | simao
# Processing Record 46 of Set 7 | new albany
# Processing Record 47 of Set 7 | yatou
# Processing Record 48 of Set 7 | tuatapere
# Processing Record 49 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 7 | touros
# Processing Record 1 of Set 8 | tomatlan
# Processing Record 2 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 3 of Set 8 | lasa
# Processing Record 4 of Set 8 | mercedes
# Processing Record 5 of Set 8 | arman
# Processing Record 6 of Set 8 | saint-francois
# Processing Record 7 of Set 8 | ojinaga
# Processing Record 8 of Set 8 | nilai
# Processing Record 9 of Set 8 | ketchikan
# Processing Record 10 of Set 8 | okhotsk
# Processing Record 11 of Set 8 | broken hill
# Processing Record 12 of Set 8 | impfondo
# Processing Record 13 of Set 8 | merauke
# Processing Record 14 of Set 8 | lebu
# Processing Record 15 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 8 | pilot butte
# Processing Record 17 of Set 8 | kavieng
# Processing Record 18 of Set 8 | churapcha
# Processing Record 19 of Set 8 | yeovil
# Processing Record 20 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 21 of Set 8 | kholodnyy
# Processing Record 22 of Set 8 | kidal
# Processing Record 23 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 8 | thompson
# Processing Record 25 of Set 8 | san patricio
# Processing Record 26 of Set 8 | riaba
# City not found. Skipping...
# Processing Record 27 of Set 8 | belsand
# Processing Record 28 of Set 8 | sao jose da coroa grande
# Processing Record 29 of Set 8 | williams lake
# Processing Record 30 of Set 8 | ambon
# Processing Record 31 of Set 8 | miquelon
# Processing Record 32 of Set 8 | carmo
# Processing Record 33 of Set 8 | coari
# Processing Record 34 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 8 | peplos
# Processing Record 36 of Set 8 | bundaberg
# Processing Record 37 of Set 8 | kahului
# Processing Record 38 of Set 8 | hovd
# Processing Record 39 of Set 8 | ust-nera
# Processing Record 40 of Set 8 | tsumeb
# Processing Record 41 of Set 8 | valparaiso
# Processing Record 42 of Set 8 | jaru
# Processing Record 43 of Set 8 | saiki
# Processing Record 44 of Set 8 | outjo
# Processing Record 45 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 8 | hellin
# Processing Record 47 of Set 8 | ostrovnoy
# Processing Record 48 of Set 8 | champerico
# Processing Record 49 of Set 8 | mount gambier
# Processing Record 50 of Set 8 | jardim
# Processing Record 1 of Set 9 | pangkalanbuun
# Processing Record 2 of Set 9 | poya
# Processing Record 3 of Set 9 | kaeo
# Processing Record 4 of Set 9 | krasnozerskoye
# Processing Record 5 of Set 9 | aizpute
# Processing Record 6 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 9 | yuzhnyy
# Processing Record 8 of Set 9 | coihaique
# Processing Record 9 of Set 9 | nabire
# Processing Record 10 of Set 9 | mokhotlong
# Processing Record 11 of Set 9 | victoria
# Processing Record 12 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 13 of Set 9 | batagay
# Processing Record 14 of Set 9 | akdepe
# Processing Record 15 of Set 9 | oranjestad
# Processing Record 16 of Set 9 | nanortalik
# Processing Record 17 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 9 | graaff-reinet
# Processing Record 19 of Set 9 | pacific grove
# Processing Record 20 of Set 9 | melfi
# Processing Record 21 of Set 9 | santa vitoria do palmar
# Processing Record 22 of Set 9 | necochea
# Processing Record 23 of Set 9 | smirnykh
# Processing Record 24 of Set 9 | dauphin
# Processing Record 25 of Set 9 | aleksandrov gay
# Processing Record 26 of Set 9 | plettenberg bay
# Processing Record 27 of Set 9 | san andres
# Processing Record 28 of Set 9 | berlevag
# Processing Record 29 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 9 | alegrete
# Processing Record 31 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 32 of Set 9 | palana
# Processing Record 33 of Set 9 | horsham
# Processing Record 34 of Set 9 | srednekolymsk
# Processing Record 35 of Set 9 | khilok
# Processing Record 36 of Set 9 | katobu
# Processing Record 37 of Set 9 | makakilo city
# Processing Record 38 of Set 9 | stornoway
# Processing Record 39 of Set 9 | xining
# Processing Record 40 of Set 9 | wasilla
# Processing Record 41 of Set 9 | boende
# Processing Record 42 of Set 9 | dingle
# Processing Record 43 of Set 9 | port lincoln
# Processing Record 44 of Set 9 | tezu
# Processing Record 45 of Set 9 | burnie
# Processing Record 46 of Set 9 | newtownards
# Processing Record 47 of Set 9 | nome
# Processing Record 48 of Set 9 | nayudupeta
# Processing Record 49 of Set 9 | viedma
# Processing Record 50 of Set 9 | lorengau
# Processing Record 1 of Set 10 | sinnamary
# Processing Record 2 of Set 10 | mikhaylovsk
# Processing Record 3 of Set 10 | keetmanshoop
# Processing Record 4 of Set 10 | kijang
# Processing Record 5 of Set 10 | norsup
# Processing Record 6 of Set 10 | muravlenko
# Processing Record 7 of Set 10 | amga
# Processing Record 8 of Set 10 | whitehorse
# Processing Record 9 of Set 10 | la ronge
# Processing Record 10 of Set 10 | ati
# Processing Record 11 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 13 of Set 10 | le pradet
# Processing Record 14 of Set 10 | longhua
# Processing Record 15 of Set 10 | beyneu
# Processing Record 16 of Set 10 | talcahuano
# Processing Record 17 of Set 10 | valle de allende
# Processing Record 18 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 19 of Set 10 | vila franca do campo
# Processing Record 20 of Set 10 | gwanda
# Processing Record 21 of Set 10 | kota tinggi
# Processing Record 22 of Set 10 | skegness
# Processing Record 23 of Set 10 | yichang
# Processing Record 24 of Set 10 | marquette
# Processing Record 25 of Set 10 | tsimlyansk
# Processing Record 26 of Set 10 | burica
# City not found. Skipping...
# Processing Record 27 of Set 10 | salmo
# Processing Record 28 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 29 of Set 10 | belaya glina
# Processing Record 30 of Set 10 | mahwa
# Processing Record 31 of Set 10 | warrnambool
# Processing Record 32 of Set 10 | manzhouli
# Processing Record 33 of Set 10 | udachnyy
# Processing Record 34 of Set 10 | buzmeyin
# Processing Record 35 of Set 10 | barcelos
# Processing Record 36 of Set 10 | huarmey
# Processing Record 37 of Set 10 | medenychi
# Processing Record 38 of Set 10 | norman wells
# Processing Record 39 of Set 10 | owando
# Processing Record 40 of Set 10 | menongue
# Processing Record 41 of Set 10 | katangli
# Processing Record 42 of Set 10 | san rafael del sur
# Processing Record 43 of Set 10 | nizhniy kuranakh
# Processing Record 44 of Set 10 | baiquan
# Processing Record 45 of Set 10 | angoche
# Processing Record 46 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 48 of Set 10 | chikoy
# City not found. Skipping...
# Processing Record 49 of Set 10 | ozieri
# Processing Record 50 of Set 10 | karachi
# Processing Record 1 of Set 11 | kropotkin
# Processing Record 2 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 11 | tiksi
# Processing Record 4 of Set 11 | turayf
# Processing Record 5 of Set 11 | matara
# Processing Record 6 of Set 11 | road town
# Processing Record 7 of Set 11 | khandbari
# Processing Record 8 of Set 11 | sur
# Processing Record 9 of Set 11 | saldanha
# Processing Record 10 of Set 11 | safford
# Processing Record 11 of Set 11 | skjervoy
# Processing Record 12 of Set 11 | weligama
# Processing Record 13 of Set 11 | conde
# Processing Record 14 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 11 | biltine
# Processing Record 16 of Set 11 | strezhevoy
# Processing Record 17 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 18 of Set 11 | troitskoye
# Processing Record 19 of Set 11 | katsuura
# Processing Record 20 of Set 11 | port-cartier
# Processing Record 21 of Set 11 | lavrentiya
# Processing Record 22 of Set 11 | sangar
# Processing Record 23 of Set 11 | meulaboh
# Processing Record 24 of Set 11 | dom pedro
# Processing Record 25 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 26 of Set 11 | honiara
# Processing Record 27 of Set 11 | inuvik
# Processing Record 28 of Set 11 | jackson
# Processing Record 29 of Set 11 | quatre cocos
# Processing Record 30 of Set 11 | buala
# Processing Record 31 of Set 11 | sibolga
# Processing Record 32 of Set 11 | mareeba
# Processing Record 33 of Set 11 | tunceli
# Processing Record 34 of Set 11 | russell
# Processing Record 35 of Set 11 | awjilah
# Processing Record 36 of Set 11 | shimoda
# Processing Record 37 of Set 11 | sayyan
# Processing Record 38 of Set 11 | taksimo
# Processing Record 39 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 11 | duldurga
# Processing Record 41 of Set 11 | sonoita
# Processing Record 42 of Set 11 | wloclawek
# Processing Record 43 of Set 11 | deogarh
# Processing Record 44 of Set 11 | nikolayevsk-na-amure
# Processing Record 45 of Set 11 | yulara
# Processing Record 46 of Set 11 | vuktyl
# Processing Record 47 of Set 11 | marrakesh
# Processing Record 48 of Set 11 | rawson
# Processing Record 49 of Set 11 | krasnoselkup
# Processing Record 50 of Set 11 | razole
# Processing Record 1 of Set 12 | pirovskoye
# Processing Record 2 of Set 12 | mitu
# Processing Record 3 of Set 12 | aksarka
# Processing Record 4 of Set 12 | san cristobal
# Processing Record 5 of Set 12 | sept-iles
# Processing Record 6 of Set 12 | comodoro rivadavia
# Processing Record 7 of Set 12 | paraiso
# Processing Record 8 of Set 12 | kwakoa
# Processing Record 9 of Set 12 | lagoa
# Processing Record 10 of Set 12 | beloha
# Processing Record 11 of Set 12 | pathein
# Processing Record 12 of Set 12 | celestun
# Processing Record 13 of Set 12 | lisala
# Processing Record 14 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 12 | igarka
# Processing Record 16 of Set 12 | saskatoon
# Processing Record 17 of Set 12 | odweyne
# Processing Record 18 of Set 12 | wanning
# Processing Record 19 of Set 12 | mayo
# Processing Record 20 of Set 12 | mumbwa
# Processing Record 21 of Set 12 | juneau
# Processing Record 22 of Set 12 | cairns
# Processing Record 23 of Set 12 | ornskoldsvik
# Processing Record 24 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 12 | adrar
# Processing Record 26 of Set 12 | tomigusuku
# Processing Record 27 of Set 12 | kyzyl-suu
# Processing Record 28 of Set 12 | tiznit
# Processing Record 29 of Set 12 | longyearbyen
# Processing Record 30 of Set 12 | pokhara
# Processing Record 31 of Set 12 | rio grande
# Processing Record 32 of Set 12 | resistencia
# Processing Record 33 of Set 12 | bardiyah
# Processing Record 34 of Set 12 | mukhen
# Processing Record 35 of Set 12 | banikoara
# Processing Record 36 of Set 12 | snezhnogorsk
# Processing Record 37 of Set 12 | castro alves
# Processing Record 38 of Set 12 | anadyr
# Processing Record 39 of Set 12 | auka
# Processing Record 40 of Set 12 | eirunepe
# Processing Record 41 of Set 12 | pizhanka
# Processing Record 42 of Set 12 | tromso
# Processing Record 43 of Set 12 | caucaia
# Processing Record 44 of Set 12 | tvoroyri
# Processing Record 45 of Set 12 | jian
# Processing Record 46 of Set 12 | naze
# Processing Record 47 of Set 12 | moussoro
# Processing Record 48 of Set 12 | coos bay
# Processing Record 49 of Set 12 | pocone
# Processing Record 50 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 1 of Set 13 | alofi
# Processing Record 2 of Set 13 | zhengjiatun
# Processing Record 3 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 13 | kismayo
# Processing Record 5 of Set 13 | omboue
# Processing Record 6 of Set 13 | kajaani
# Processing Record 7 of Set 13 | markha
# Processing Record 8 of Set 13 | iranshahr
# Processing Record 9 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 13 | kurtalan
# Processing Record 11 of Set 13 | czluchow
# Processing Record 12 of Set 13 | westport
# Processing Record 13 of Set 13 | wucheng
# Processing Record 14 of Set 13 | ostersund
# Processing Record 15 of Set 13 | loiza
# Processing Record 16 of Set 13 | kampot
# Processing Record 17 of Set 13 | goderich
# Processing Record 18 of Set 13 | chornobay
# Processing Record 19 of Set 13 | mapiripan
# Processing Record 20 of Set 13 | namatanai
# Processing Record 21 of Set 13 | yar-sale
# Processing Record 22 of Set 13 | maniitsoq
# Processing Record 23 of Set 13 | the valley
# Processing Record 24 of Set 13 | ilovlya
# Processing Record 25 of Set 13 | umea
# Processing Record 26 of Set 13 | pocatello
# Processing Record 27 of Set 13 | ha
# City not found. Skipping...
# Processing Record 28 of Set 13 | kologriv
# Processing Record 29 of Set 13 | gornozavodsk
# Processing Record 30 of Set 13 | buin
# Processing Record 31 of Set 13 | aksu
# Processing Record 32 of Set 13 | narsaq
# Processing Record 33 of Set 13 | pandaria
# Processing Record 34 of Set 13 | marshall
# Processing Record 35 of Set 13 | deep river
# Processing Record 36 of Set 13 | naushki
# Processing Record 37 of Set 13 | urdoma
# Processing Record 38 of Set 13 | palau
# Processing Record 39 of Set 13 | yarmouth
# Processing Record 40 of Set 13 | pamekasan
# Processing Record 41 of Set 13 | yumen
# Processing Record 42 of Set 13 | primorsk
# Processing Record 43 of Set 13 | aanekoski
# Processing Record 44 of Set 13 | galesong
# Processing Record 45 of Set 13 | pueblo bello
# Processing Record 46 of Set 13 | biak
# Processing Record 47 of Set 13 | dehloran
# Processing Record 48 of Set 13 | mezhova
# Processing Record 49 of Set 13 | zhigansk
# Processing Record 50 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 14 | korla
# Processing Record 2 of Set 14 | dingli
# Processing Record 3 of Set 14 | birjand
# Processing Record 4 of Set 14 | udupi
# Processing Record 5 of Set 14 | pierre
# Processing Record 6 of Set 14 | safakulevo
# Processing Record 7 of Set 14 | ust-kulom
# Processing Record 8 of Set 14 | le port
# Processing Record 9 of Set 14 | beocin
# Processing Record 10 of Set 14 | sabha
# Processing Record 11 of Set 14 | kawalu
# Processing Record 12 of Set 14 | gizo
# Processing Record 13 of Set 14 | visnes
# Processing Record 14 of Set 14 | umba
# Processing Record 15 of Set 14 | nikolsk
# Processing Record 16 of Set 14 | bosanski novi
# Processing Record 17 of Set 14 | nouadhibou
# Processing Record 18 of Set 14 | tshikapa
# Processing Record 19 of Set 14 | luderitz
# Processing Record 20 of Set 14 | parfino
# Processing Record 21 of Set 14 | fairbanks
# Processing Record 22 of Set 14 | sistranda
# Processing Record 23 of Set 14 | severobaykalsk
# Processing Record 24 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 14 | araioses
# Processing Record 26 of Set 14 | maragogi
# Processing Record 27 of Set 14 | vigrestad
# Processing Record 28 of Set 14 | mafinga
# Processing Record 29 of Set 14 | nantucket
# Processing Record 30 of Set 14 | anahuac
# Processing Record 31 of Set 14 | baraki barak
# Processing Record 32 of Set 14 | nagornskiy
# Processing Record 33 of Set 14 | kameno
# Processing Record 34 of Set 14 | broome
# Processing Record 35 of Set 14 | hibbing
# Processing Record 36 of Set 14 | zonalnoye
# City not found. Skipping...
# Processing Record 37 of Set 14 | prince rupert
# Processing Record 38 of Set 14 | sao gabriel da cachoeira
# Processing Record 39 of Set 14 | mahibadhoo
# Processing Record 40 of Set 14 | benguela
# Processing Record 41 of Set 14 | moundsville
# Processing Record 42 of Set 14 | ambovombe
# Processing Record 43 of Set 14 | high rock
# Processing Record 44 of Set 14 | pangnirtung
# Processing Record 45 of Set 14 | ancud
# Processing Record 46 of Set 14 | big spring
# Processing Record 47 of Set 14 | careiro da varzea
# Processing Record 48 of Set 14 | polazna
# Processing Record 49 of Set 14 | cam ranh
# Processing Record 50 of Set 14 | yeppoon
# Processing Record 1 of Set 15 | flin flon
# Processing Record 2 of Set 15 | bang saphan
# Processing Record 3 of Set 15 | sebring
# Processing Record 4 of Set 15 | redcar
# Processing Record 5 of Set 15 | karaton
# Processing Record 6 of Set 15 | anchorage
# Processing Record 7 of Set 15 | oussouye
# Processing Record 8 of Set 15 | kalmunai
# Processing Record 9 of Set 15 | strai
# Processing Record 10 of Set 15 | banjarmasin
# Processing Record 11 of Set 15 | homestead
# Processing Record 12 of Set 15 | santa cruz de la palma
# Processing Record 13 of Set 15 | luau
# Processing Record 14 of Set 15 | tiarei
# Processing Record 15 of Set 15 | beinamar
# Processing Record 16 of Set 15 | ola
# Processing Record 17 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 15 | presidencia roque saenz pena
# Processing Record 19 of Set 15 | kankaanpaa
# Processing Record 20 of Set 15 | maarianhamina
# Processing Record 21 of Set 15 | usinsk
# Processing Record 22 of Set 15 | byron bay
# Processing Record 23 of Set 15 | asyut
# Processing Record 24 of Set 15 | burias
# Processing Record 25 of Set 15 | bridlington
# Processing Record 26 of Set 15 | skender vakuf
# Processing Record 27 of Set 15 | fort nelson
# Processing Record 28 of Set 15 | gazni
# City not found. Skipping...
# Processing Record 29 of Set 15 | severomuysk
# Processing Record 30 of Set 15 | tres arroyos
# Processing Record 31 of Set 15 | tianpeng
# Processing Record 32 of Set 15 | carbondale
# Processing Record 33 of Set 15 | mildura
# Processing Record 34 of Set 15 | baykit
# Processing Record 35 of Set 15 | la sarre
# Processing Record 36 of Set 15 | green river
# Processing Record 37 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 15 | ajdabiya
# Processing Record 39 of Set 15 | brekstad
# Processing Record 40 of Set 15 | mwinilunga
# Processing Record 41 of Set 15 | tanete
# Processing Record 42 of Set 15 | xai-xai
# Processing Record 43 of Set 15 | ambilobe
# Processing Record 44 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 45 of Set 15 | mae sai
# Processing Record 46 of Set 15 | raga
# Processing Record 47 of Set 15 | morondava
# Processing Record 48 of Set 15 | puerto escondido
# Processing Record 49 of Set 15 | zemio
# Processing Record 50 of Set 15 | bayanday
# Processing Record 1 of Set 16 | trinidad
# Processing Record 2 of Set 16 | zima
# Processing Record 3 of Set 16 | gigmoto
# Processing Record 4 of Set 16 | sterlibashevo
# Processing Record 5 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 16 | pangai
# Processing Record 7 of Set 16 | kazuno
# Processing Record 8 of Set 16 | luganville
# Processing Record 9 of Set 16 | ondjiva
# Processing Record 10 of Set 16 | abonnema
# Processing Record 11 of Set 16 | mackay
# Processing Record 12 of Set 16 | rach gia
# Processing Record 13 of Set 16 | cap malheureux
# Processing Record 14 of Set 16 | los llanos de aridane
# Processing Record 15 of Set 16 | avera
# Processing Record 16 of Set 16 | san carlos de bariloche
# Processing Record 17 of Set 16 | batemans bay
# Processing Record 18 of Set 16 | acarau
# Processing Record 19 of Set 16 | chisec
# Processing Record 20 of Set 16 | houma
# Processing Record 21 of Set 16 | padang
# Processing Record 22 of Set 16 | encheng
# Processing Record 23 of Set 16 | mitsamiouli
# Processing Record 24 of Set 16 | oskarshamn
# Processing Record 25 of Set 16 | cabra
# Processing Record 26 of Set 16 | taburao
# City not found. Skipping...
# Processing Record 27 of Set 16 | liaoyang
# Processing Record 28 of Set 16 | massakory
# Processing Record 29 of Set 16 | tevaitoa
# Processing Record 30 of Set 16 | yamaga
# Processing Record 31 of Set 16 | chapais
# Processing Record 32 of Set 16 | qaqortoq
# Processing Record 33 of Set 16 | havoysund
# Processing Record 34 of Set 16 | oranjemund
# Processing Record 35 of Set 16 | olafsvik
# Processing Record 36 of Set 16 | markova
# Processing Record 37 of Set 16 | zhezkazgan
# Processing Record 38 of Set 16 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 16 | slavonski brod
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Saint George  37.1041 -113.5841     90.19        19           0
# 1           Bozeman  45.6796 -111.0386     69.22        57           0
# 2            Taltal -25.4000  -70.4833     58.39        69           0
# 3           Ushuaia -54.8000  -68.3000     40.66        65          40
# 4              Hofn  64.2539  -15.2082     40.41        53          48
# ..              ...      ...       ...       ...       ...         ...
# 716      Oranjemund -28.5500   16.4333     52.16        89           0
# 717        Olafsvik  64.8945  -23.7142     44.10        47         100
# 718         Markova  48.6758   24.4138     51.46        94          97
# 719      Zhezkazgan  47.8043   67.7144     46.38        61           0
# 720  Slavonski Brod  45.1603   18.0156     54.37        98          29
#
#      Wind Speed Country                 Date City_weather
# 0          3.44      US  2022-09-27 02:21:04        Clear
# 1          6.91      US  2022-09-27 02:21:04        Clear
# 2          5.35      CL  2022-09-27 02:21:05        Clear
# 3         13.80      AR  2022-09-27 02:17:51       Clouds
# 4         22.57      IS  2022-09-27 02:21:05       Clouds
# ..          ...     ...                  ...          ...
# 716        2.62      NA  2022-09-27 02:47:15        Clear
# 717       10.38      IS  2022-09-27 02:47:15       Clouds
# 718        0.18      UA  2022-09-27 02:47:15       Clouds
# 719       11.18      KZ  2022-09-27 02:47:15        Clear
# 720        1.79      HR  2022-09-27 02:47:16       Clouds
#
# [721 rows x 10 columns]

# %%
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 
                    'Max Temp', 'Humidity', 'Cloudiness',
                    'Wind Speed', 'City_weather']

# %%
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country                 Date      Lat       Lng  Max Temp  \
# 0      Saint George      US  2022-09-27 02:21:04  37.1041 -113.5841     90.19
# 1           Bozeman      US  2022-09-27 02:21:04  45.6796 -111.0386     69.22
# 2            Taltal      CL  2022-09-27 02:21:05 -25.4000  -70.4833     58.39
# 3           Ushuaia      AR  2022-09-27 02:17:51 -54.8000  -68.3000     40.66
# 4              Hofn      IS  2022-09-27 02:21:05  64.2539  -15.2082     40.41
# ..              ...     ...                  ...      ...       ...       ...
# 716      Oranjemund      NA  2022-09-27 02:47:15 -28.5500   16.4333     52.16
# 717        Olafsvik      IS  2022-09-27 02:47:15  64.8945  -23.7142     44.10
# 718         Markova      UA  2022-09-27 02:47:15  48.6758   24.4138     51.46
# 719      Zhezkazgan      KZ  2022-09-27 02:47:15  47.8043   67.7144     46.38
# 720  Slavonski Brod      HR  2022-09-27 02:47:16  45.1603   18.0156     54.37
#
#      Humidity  Cloudiness  Wind Speed City_weather
# 0          19           0        3.44        Clear
# 1          57           0        6.91        Clear
# 2          69           0        5.35        Clear
# 3          65          40       13.80       Clouds
# 4          53          48       22.57       Clouds
# ..        ...         ...         ...          ...
# 716        89           0        2.62        Clear
# 717        47         100       10.38       Clouds
# 718        94          97        0.18       Clouds
# 719        61           0       11.18        Clear
# 720        98          29        1.79       Clouds
#
# [721 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = r'Weather_Databases/WeatherPy_Database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
